# %%
import pandas as pd
df = pd.read_csv
# Out:
#                   Area_type   Availability  Total_sqft  \
# 0      Super built-up  Area         19-Dec      1056.0
# 1                Plot  Area  Ready To Move      2600.0
# 2            Built-up  Area  Ready To Move      1440.0
# 3      Super built-up  Area  Ready To Move      1521.0
# 4      Super built-up  Area  Ready To Move      1200.0
# ...                     ...            ...         ...
# 13315        Built-up  Area  Ready To Move      3453.0
# 13316  Super built-up  Area  Ready To Move      3600.0
# 13317        Built-up  Area  Ready To Move      1141.0
# 13318  Super built-up  Area         18-Jun      4689.0
# 13319  Super built-up  Area  Ready To Move       550.0
#
#                        Location  Size  Bathrooms  Balcony      Price₹
# 0      Electronic City Phase II     2        2.0      1.0   3,907,000
# 1              Chikka Tirupathi     4        5.0      3.0  12,000,000
# 2                   Uttarahalli     3        2.0      3.0   6,200,000
# 3            Lingadheeranahalli     3        3.0      1.0   9,500,000
# 4                      Kothanur     2        2.0      1.0   5,100,000
# ...                         ...   ...        ...      ...         ...
# 13315                Whitefield     5        4.0      0.0  23,100,000
# 13316             Richards Town     4        5.0      2.0  40,000,000
# 13317     Raja Rajeshwari Nagar     2        2.0      1.0   6,000,000
# 13318           Padmanabhanagar     4        4.0      1.0  48,800,000
# 13319              Doddathoguru     1        1.0      1.0   1,700,000
#
# [13320 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

custom_colors = ['#3497af', '#8d6041', '#3a2c4f', '#343630']

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='Area_type', hue='Area_type', palette=custom_colors,legend=True)
plt.title("Properties Count by Area Type")
plt.xlabel("Area Type")
plt.ylabel("Count")
plt.xticks(rotation=10)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Price₹'], bins=20, color='#a43165')
plt.title("Price Distribution")
plt.xlabel("Price₹")
plt.ylabel("Number of Properties")
plt.show()

# %%
plt.figure(figsize=(6, 4))

custom_colors = ['#cbe50c', '#1ad015', '#0ce5d5', '#e50cd5']


sns.scatterplot(x='Total_sqft', y='Price₹', data=df, hue='Area_type', palette=custom_colors)
plt.title("Sqft vs Price by Area Type")
plt.xlabel("Total Sqft")
plt.ylabel("Price₹")
plt.legend(title='Area Type')
plt.show()

# %%
df.to_csv('Madhubalan001_viz.csv',index =False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area_type     13320 non-null  object
#  1   Availability  13320 non-null  object
#  2   Total_sqft    13320 non-null  float64
#  3   Location      13320 non-null  object
#  4   Size          13320 non-null  int64
#  5   Bathrooms     13320 non-null  float64
#  6   Balcony       13320 non-null  float64
#  7   Price₹        13320 non-null  int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 832.6+ KB

# %%
import os
print("Madhubalan001_viz.csv" in os.listdir())
# Out:
# True
